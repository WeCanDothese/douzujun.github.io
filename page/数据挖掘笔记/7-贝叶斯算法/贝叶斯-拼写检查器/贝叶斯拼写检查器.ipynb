# %% [markdown]
# ###  贝叶斯拼写检查器 ###

# %%
import re, collections
 
def words(text): return re.findall('[a-z]+', text.lower()) 
 
def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model
 
NWORDS = train(words(open('big.txt').read()))
 
alphabet = 'abcdefghijklmnopqrstuvwxyz'
 
def edits1(word):
    n = len(word)
    return set([word[0:i]+word[i+1:] for i in range(n)] +                     # deletion
               [word[0:i]+word[i+1]+word[i]+word[i+2:] for i in range(n-1)] + # transposition
               [word[0:i]+c+word[i+1:] for i in range(n) for c in alphabet] + # alteration
               [word[0:i]+c+word[i:] for i in range(n+1) for c in alphabet])  # insertion
 
def known_edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1) if e2 in NWORDS)
 
def known(words): return set(w for w in words if w in NWORDS)
 
def correct(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
    return max(candidates, key=lambda w: NWORDS[w])

# %%
# words("asdf. ASF asd *()asf")

# %%
#appl #appla #learw #tess #morw
correct('knon')
# Out:
# 'know'

# %% [markdown]
# ### 求解：argmaxc P(c|w) -> argmaxc P(w|c) P(c) / P(w) ###
#
# * P(c), 文章中出现一个正确拼写词 c 的概率, 也就是说, 在英语文章中, c 出现的概率有多大
# * P(w|c), 在用户想键入 c 的情况下敲成 w 的概率. 因为这个是代表用户会以多大的概率把 c 敲错成 w
# * argmaxc, 用来枚举所有可能的 c 并且选取概率最大的

# %%
# 把语料中的单词全部抽取出来, 转成小写, 并且去除单词中间的特殊符号
def words(text): return re.findall('[a-z]+', text.lower()) 
 
def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model
 
NWORDS = train(words(open('big.txt').read()))

# %% [markdown]
# 要是遇到我们从来没有过见过的新词怎么办. 假如说一个词拼写完全正确, 但是语料库中没有包含这个词, 从而这个词也永远不会出现在训练集中. 于是, 我们就要返回出现这个词的概率是0. 这个情况不太妙, 因为概率为0这个代表了这个事件绝对不可能发生, 而在我们的概率模型中, 我们期望用一个很小的概率来代表这种情况. lambda: 1

# %%
NWORDS
# Out:
# defaultdict(<function __main__.train.<locals>.<lambda>>,
#             {'tiller': 3,
#              'bodied': 5,
#              'illustrating': 6,
#              'series': 129,
#              'playful': 7,
#              'fibrosis': 7,
#              'informally': 2,
#              'inequality': 3,
#              'liking': 10,
#              'consoling': 6,
#              'gaspee': 4,
#              'goal': 29,
#              'recounts': 2,
#              'wincing': 6,
#              'citadel': 6,
#              'remortgaged': 2,
#              'strife': 10,
#              'genus': 2,
#              'displacement': 27,
#              'notebook': 10,
#              'apprentices': 3,
#              'mississippi': 79,
#              'debt': 66,
#              'terentich': 5,
#              'bargain': 14,
#              'handed': 81,
#              'flour': 15,
#              'smolensk': 103,
#              'gangs': 3,
#              'colleges': 12,
#              'guesses': 2,
#              'crumbly': 2,
#              'bacterial': 55,
#              'independence': 152,
#              'ricans': 2,
#              'fenton': 3,
#              'pain': 304,
#              'ere': 2,
#              'entailed': 4,
#              'exfoliation': 3,
#              'aversion': 6,
#              'kiril': 6,
#              'biggest': 2,
#              'picking': 16,
#              'bedroom': 46,
#              'tenaciously': 5,
#              'minims': 7,
#              'certain': 362,
#              'schlappanitz': 5,
#              'insulating': 3,
#              'distinctive': 8,
#              'appealing': 6,
#              'debts': 63,
#              'angling': 3,
#              'juncture': 7,
#              'revered': 2,
#              'dickinson': 2,
#              'repassed': 2,
#              'moreau': 6,
#              'lack': 34,
#              'habitually': 3,
#              'loquacity': 2,
#              'infringes': 2,
#              'planking': 2,
#              'archbishop': 4,
#              'favored': 43,
#              'heard': 637,
#              'petrovna': 4,
#              'rib': 9,
#              'twos': 4,
#              'roman': 9,
#              'courting': 3,
#              'exclude': 15,
#              'septique': 3,
#              'injuriously': 4,
#              'cylindrical': 2,
#              'ash': 6,
#              'charcot': 20,
#              'fatty': 24,
#              'cardiac': 15,
#              'troubles': 26,
#              'pillaged': 4,
#              'convention': 152,
#              'fruschtique': 2,
#              'penny': 8,
#              'irritative': 3,
#              'diligently': 4,
#              'centuries': 13,
#              'abdicate': 2,
#              'jones': 25,
#              'investing': 4,
#              'laminated': 17,
#              'disinclined': 3,
#              'bathhouse': 3,
#              'seasons': 4,
#              'excavation': 3,
#              'mugwump': 3,
#              'turns': 27,
#              'weported': 2,
#              'threatens': 8,
#              'naphthol': 2,
#              'amusing': 25,
#              'exhibit': 19,
#              'condensing': 2,
#              'hospital': 47,
#              'bulb': 3,
#              'inaugurated': 17,
#              'muse': 2,
#              'buyers': 3,
#              'seller': 6,
#              'samples': 2,
#              'ascertaining': 5,
#              'trepoff': 2,
#              'intervening': 10,
#              'authorise': 2,
#              'coalition': 5,
#              'poisons': 7,
#              'edmund': 13,
#              'imaginary': 8,
#              'motile': 6,
#              'amoureuse': 2,
#              'sloughy': 4,
#              'capabilities': 3,
#              'tarsal': 5,
#              'ineffectually': 2,
#              'animus': 2,
#              'patrolling': 2,
#              'brightest': 5,
#              'pacifying': 3,
#              'negotiate': 13,
#              'longitude': 3,
#              'outside': 111,
#              'mingle': 5,
#              'kepler': 2,
#              'enwrapped': 2,
#              'deluding': 2,
#              'gates': 35,
#              'diluent': 2,
#              'maps': 8,
#              'doses': 29,
#              'abrogated': 2,
#              'odd': 10,
#              'serviceable': 4,
#              'folly': 20,
#              'blackened': 6,
#              'inventories': 2,
#              'developments': 4,
#              'hernia': 14,
#              'osteo': 18,
#              'greenback': 7,
#              'reviewing': 5,
#              'mightier': 3,
#              'suited': 16,
#              'sanction': 10,
#              'wandered': 16,
#              'smoked': 12,
#              'prevailed': 17,
#              'verrons': 2,
#              'carryings': 2,
#              'allies': 23,
#              'bristling': 3,
#              'occurrences': 8,
#              'earlier': 34,
#              'crops': 25,
#              'caravans': 3,
#              'complimented': 4,
#              'armies': 63,
#              'instrument': 36,
#              'composure': 11,
#              'portly': 7,
#              'dogma': 2,
#              'yet': 489,
#              'saxe': 8,
#              'profoundly': 18,
#              'jarring': 3,
#              'loath': 2,
#              'joyful': 50,
#              'dolls': 2,
#              'dumping': 2,
#              'unhindered': 3,
#              'trigeminal': 5,
#              'transference': 11,
#              'sabre': 10,
#              'cain': 2,
#              'wordy': 2,
#              'instructive': 11,
#              'merveille': 2,
#              'executioner': 6,
#              'xxxiii': 3,
#              'outfits': 2,
#              'cox': 3,
#              'atkinson': 2,
#              'unerring': 2,
#              'kocher': 5,
#              'combating': 7,
#              'heaps': 4,
#              'feat': 5,
#              'infiltrations': 2,
#              'stout': 63,
#              'wince': 3,
#              'melaena': 4,
#              'archives': 2,
#              'mot': 8,
#              'shiny': 10,
#              'disillusioned': 3,
#              'security': 22,
#              'negroes': 28,
#              'shunned': 2,
#              'fund': 15,
#              'dupes': 2,
#              'plethoric': 2,
#              'hosmer': 26,
#              'updated': 5,
#              'intent': 14,
#              'colic': 3,
#              'workplace': 2,
#              'maimed': 4,
#              'inauguration': 17,
#              'onychia': 11,
#              'once': 570,
#              'disaster': 17,
#              'extinct': 3,
#              'vara': 3,
#              'insists': 3,
#              'hereford': 3,
#              'canteen': 7,
#              'flashes': 4,
#              'caps': 20,
#              'apology': 13,
#              'fe': 9,
#              'alternation': 2,
#              'supervised': 2,
#              'caustique': 3,
#              'tollers': 2,
#              'abbe': 20,
#              'woolly': 2,
#              'ate': 22,
#              'capsulatus': 4,
#              'cruelty': 26,
#              'expired': 4,
#              'cheerfulness': 6,
#              'supplied': 37,
#              'countrymen': 25,
#              'trophy': 5,
#              'saints': 10,
#              'confers': 3,
#              'frontiersman': 3,
#              'faneuils': 2,
#              'arduous': 8,
#              'want': 324,
#              'engine': 14,
#              'booked': 2,
#              'entente': 2,
#              'excursion': 4,
#              'madrid': 9,
#              'pressure': 236,
#              'beef': 11,
#              'duly': 17,
#              'lowell': 14,
#              'retires': 4,
#              'caseful': 2,
#              'ras': 2,
#              'excised': 21,
#              'gape': 8,
#              'inscription': 6,
#              'haziness': 3,
#              'impetigo': 2,
#              'metallic': 17,
#              'wholly': 16,
#              'naught': 6,
#              'nikitenko': 2,
#              'mediator': 3,
#              'padlocked': 2,
#              'vincent': 11,
#              'velvet': 19,
#              'peritoneal': 16,
#              'athwart': 3,
#              'arms': 250,
#              'vaginal': 4,
#              'scholarship': 3,
#              'semen': 2,
#              'ballasted': 2,
#              'usurped': 2,
#              'upraised': 3,
#              'experiencing': 10,
#              'initial': 20,
#              'connivance': 3,
#              'contributes': 2,
#              'rarefaction': 6,
#              'mountains': 28,
#              'tails': 5,
#              'nod': 9,
#              'darted': 10,
#              'cyrus': 2,
#              'hairless': 2,
#              'height': 37,
#              'proteolytic': 2,
#              'caucuses': 4,
#              'pass': 155,
#              'enmity': 6,
#              'monomaniac': 2,
#              'tenderness': 97,
#              'elicited': 16,
#              'dakotans': 2,
#              'reigns': 5,
#              'replacing': 6,
#              'nocturnal': 7,
#              'skylight': 5,
#              'callender': 24,
#              'cleanse': 6,
#              'pitting': 5,
#              'seward': 12,
#              'forehead': 67,
#              'labors': 20,
#              'precautions': 15,
#              'dampness': 2,
#              'abomination': 2,
#              'being': 919,
#              'theorist': 5,
#              'convulsed': 3,
#              'bobtail': 2,
#              'arborescent': 11,
#              'goods': 82,
#              'fluctuating': 14,
#              'marker': 3,
#              'fat': 90,
#              'coerce': 3,
#              'headway': 2,
#              'jabbering': 3,
#              'civilisation': 3,
#              'fraenkel': 6,
#              'closet': 2,
#              'courage': 42,
#              'fascia': 42,
#              'mortifying': 2,
#              'foremen': 2,
#              'slogan': 8,
#              'martyrs': 2,
#              'payments': 14,
#              'cessation': 6,
#              'baltic': 2,
#              'equations': 3,
#              'arriving': 19,
#              'affluents': 2,
#              'cynical': 4,
#              'witing': 2,
#              'forwarded': 5,
#              'discomforts': 2,
#              'poverty': 27,
#              'napoleonic': 17,
#              'understand': 413,
#              'appeasing': 2,
#              'lightened': 2,
#              'toulon': 5,
#              'hydrogen': 13,
#              'wholesome': 5,
#              'honestly': 8,
#              'eggs': 9,
#              'aden': 2,
#              'disbelieving': 2,
#              'washerwomen': 2,
#              'xxx': 3,
#              'offender': 4,
#              'bony': 38,
#              'injunction': 13,
#              'stillness': 16,
#              'deplorable': 4,
#              'sprinkled': 8,
#              'irrigated': 5,
#              'jimmy': 2,
#              'oceanic': 2,
#              'lucretia': 2,
#              'zen': 2,
#              'creditor': 3,
#              'wenches': 2,
#              'bolted': 4,
#              'fissures': 6,
#              'salary': 14,
#              'intermuscular': 6,
#              'strange': 221,
#              'cossacks': 85,
#              'intrepid': 3,
#              'bombs': 5,
#              'resemble': 33,
#              'instances': 26,
#              'bosse': 3,
#              'undismayed': 3,
#              'guryev': 3,
#              'calvin': 3,
#              'insulted': 12,
#              'grs': 3,
#              'enchantment': 3,
#              'lagging': 6,
#              'usually': 530,
#              'summonses': 2,
#              'group': 140,
#              'heaved': 8,
#              'noblemen': 6,
#              'emerson': 7,
#              'waterways': 7,
#              'lascar': 13,
#              'guessed': 22,
#              'slovenly': 2,
#              'resurrection': 2,
#              'ingratiate': 3,
#              'owen': 2,
#              'wasps': 3,
#              'arc': 6,
#              'furies': 2,
#              'penis': 17,
#              'defile': 3,
#              'cambridge': 8,
#              'friedlander': 4,
#              'flattered': 18,
#              'albuminous': 2,
#              'dura': 4,
#              'recovered': 33,
#              'groomed': 5,
#              'township': 5,
#              'debs': 7,
#              'septicaemia': 16,
#              'pokers': 2,
#              'resorts': 2,
#              'glow': 23,
#              'disentangle': 2,
#              'scaly': 5,
#              'solvent': 2,
#              'locks': 7,
#              'demanding': 13,
#              'kill': 58,
#              'sickle': 5,
#              'innervated': 3,
#              'disabilities': 10,
#              'pollen': 4,
#              'voltorn': 2,
#              'percussion': 5,
#              'exercise': 55,
#              'carlton': 5,
#              'devitalised': 13,
#              'clanging': 4,
#              'proteins': 4,
#              'willing': 26,
#              'marauders': 10,
#              'multilocular': 6,
#              'players': 7,
#              'spears': 2,
#              'prescribe': 7,
#              'emphasize': 5,
#              'gravid': 2,
#              'flogging': 4,
#              'through': 816,
#              'metastasis': 12,
#              'rensselaer': 2,
#              'peck': 3,
#              'explanation': 59,
#              'adorers': 2,
#              'absence': 99,
#              'hyoid': 4,
#              'displaced': 22,
#              'foo': 2,
#              'immature': 3,
#              'endearments': 2,
#              'belated': 4,
#              'serums': 4,
#              'sycosis': 2,
#              'salutary': 4,
#              'perfect': 40,
#              'lafa': 2,
#              'confronting': 3,
#              'desire': 97,
#              'slipped': 31,
#              'bleed': 21,
#              'effrontery': 2,
#              'colonies': 208,
#              'discoverable': 4,
#              'testified': 2,
#              'bombarded': 2,
#              'saves': 2,
#              'businessmen': 3,
#              'devils': 13,
#              'misgivings': 7,
#              'ancestry': 2,
#              'another': 842,
#              'decrees': 8,
#              'purge': 3,
#              'darlings': 3,
#              'galleries': 2,
#              'leo': 7,
#              'precluding': 2,
#              'deuce': 4,
#              'strangle': 3,
#              'joshua': 3,
#              'photographic': 2,
#              'bosoms': 2,
#              'flows': 7,
#              'ammoniated': 2,
#              'manifold': 4,
#              'kramm': 3,
#              'arabum': 2,
#              'punctuation': 7,
#              'justifications': 7,
#              'lymphocytosis': 3,
#              'neighborhood': 12,
#              'contributed': 13,
#              'enact': 12,
#              'tidings': 6,
#              'recommence': 2,
#              'handicaps': 3,
#              'bombard': 2,
#              'clinked': 2,
#              'intrusted': 8,
#              'doorway': 17,
#              'wildly': 9,
#              'covent': 4,
#              'probability': 13,
#              'craggy': 2,
#              'nucleinate': 3,
#              'sphincters': 2,
#              'establishment': 41,
#              'monitress': 3,
#              'crepitus': 4,
#              'conveys': 3,
#              'triviality': 2,
#              'friendliest': 2,
#              'pneumonia': 15,
#              'fate': 99,
#              'elongates': 2,
#              'hospitals': 19,
#              'concentrating': 6,
#              'wooing': 3,
#              'dunyasha': 35,
#              'legislative': 32,
#              'acreage': 2,
#              'spell': 10,
#              'entailing': 4,
#              'renovation': 2,
#              'unravel': 3,
#              'handicapped': 6,
#              'mainstream': 2,
#              'praying': 8,
#              'poisonous': 5,
#              'listlessly': 2,
#              'rebirth': 2,
#              'curtail': 2,
#              'theorists': 4,
#              'arbitrators': 2,
#              'freedman': 3,
#              'diplomatist': 10,
#              'pursues': 2,
#              'arrange': 35,
#              'chaffingly': 2,
#              'protective': 54,
#              'clutches': 5,
#              'framework': 24,
#              'curtseying': 2,
#              'assented': 15,
#              'stupidity': 12,
#              'agate': 3,
#              'gummatous': 32,
#              'surnames': 2,
#              'historical': 66,
#              'aye': 4,
#              'enactment': 10,
#              'peasants': 128,
#              'study': 145,
#              'hearing': 94,
#              'alkaline': 6,
#              'clear': 234,
#              'horrible': 28,
#              'funding': 14,
#              'refrain': 21,
#              'amounts': 7,
#              'accumulated': 14,
#              'duelist': 3,
#              'lowliest': 2,
#              'rats': 3,
#              'broadest': 4,
#              'trakh': 2,
#              'module': 2,
#              'deafened': 4,
#              'repugnance': 3,
#              'missions': 4,
#              'paraissent': 2,
#              'indestructible': 3,
#              'contended': 10,
#              'points': 84,
#              'limited': 81,
#              'volga': 2,
#              'nourishment': 14,
#              'questionnaire': 2,
#              'kaluga': 28,
#              'stupider': 2,
#              'sudden': 80,
#              'rioting': 8,
#              'perplexing': 11,
#              'finder': 2,
#              'newsletters': 3,
#              'tourniquet': 27,
#              'tobacco': 49,
#              'backbiter': 2,
#              'nut': 11,
#              'majority': 122,
#              'destroyed': 128,
#              'note': 116,
#              'regulations': 20,
#              'deafening': 13,
#              'metaphor': 2,
#              'disconcerting': 2,
#              'codes': 10,
#              'plea': 21,
#              'anglaise': 4,
#              'appropriating': 2,
#              'dedicated': 14,
#              'ardent': 15,
#              'illicit': 2,
#              'sharpened': 5,
#              'rhymes': 2,
#              'incompetent': 5,
#              'ledderhose': 2,
#              'pockets': 20,
#              'cracking': 6,
#              'onlookers': 6,
#              'boone': 14,
#              'taciturn': 8,
#              'mitrich': 4,
#              'massacre': 12,
#              'frequently': 219,
#              'chins': 2,
#              'consoled': 5,
#              'ii': 78,
#              'anastomosis': 8,
#              'maudlin': 2,
#              'caret': 2,
#              'leggings': 2,
#              'hind': 10,
#              'kremenchug': 2,
#              'splitting': 3,
#              'rover': 2,
#              'grenadiers': 9,
#              'born': 39,
#              'abdicated': 2,
#              'familiarity': 9,
#              'blandly': 10,
#              'ischias': 3,
#              'afresh': 12,
#              'buonapartes': 2,
#              'melanotic': 19,
#              'seminar': 2,
#              'filial': 3,
#              'loneliness': 5,
#              'hyperostosis': 13,
#              'adept': 5,
#              'entails': 4,
#              'eminence': 4,
#              'upbraided': 2,
#              'rubbles': 2,
#              'charleston': 25,
#              'jurisprudence': 10,
#              'astuteness': 2,
#              'urethritis': 4,
#              'expressly': 14,
#              'miraculous': 3,
#              'confirmation': 13,
#              'hotch': 2,
#              'mysteriously': 4,
#              'used': 277,
#              'scream': 15,
#              'circumspectly': 3,
#              'glanced': 177,
#              'ensue': 23,
#              'slab': 5,
#              'palpated': 5,
#              'island': 76,
#              'bandage': 50,
#              'fragment': 17,
#              'zero': 6,
#              'talkers': 2,
#              'masterpiece': 2,
#              'glided': 8,
#              'dispense': 8,
#              'plentiful': 8,
#              'dowry': 12,
#              'plexus': 21,
#              'augments': 2,
#              'revival': 8,
#              'perturb': 2,
#              'graft': 19,
#              'rampart': 6,
#              'bubbles': 2,
#              'u': 26,
#              'spark': 8,
#              'venezuela': 16,
#              'richly': 4,
#              'ornaments': 4,
#              'individuality': 5,
#              'audible': 24,
#              'antipyrin': 2,
#              'certificate': 3,
#              'seemliness': 2,
#              'ballots': 4,
#              'defect': 24,
#              'disciplinarian': 3,
#              'graceful': 12,
#              'insanity': 8,
#              'diese': 2,
#              'dreamy': 4,
#              'excellence': 5,
#              'rides': 7,
#              'abnormal': 29,
#              'referred': 68,
#              'banish': 2,
#              'wresting': 2,
#              'skirmishers': 5,
#              'undulating': 2,
#              'gamut': 2,
#              'steadily': 42,
#              'jump': 17,
#              'nonperformance': 2,
#              'advsh': 5,
#              'shakes': 2,
#              'anticipating': 5,
#              'accessible': 12,
#              'baits': 2,
#              'medicinal': 5,
#              'enveloped': 12,
#              'masha': 9,
#              'charpie': 2,
#              'illiteracy': 6,
#              'peaceful': 31,
#              'disclosure': 2,
#              'wayward': 2,
#              'anthrax': 21,
#              'georgetown': 2,
#              'neared': 2,
#              'robertson': 2,
#              'laborer': 6,
#              'babcock': 3,
#              'ring': 56,
#              'corns': 11,
#              'issue': 102,
#              'pockmarked': 8,
#              'cleared': 54,
#              'shipyards': 3,
#              'glen': 2,
#              'mercurial': 6,
#              'predict': 3,
#              'immersion': 7,
#              'stupor': 2,
#              'awkward': 37,
#              'snarl': 3,
#              'dusky': 10,
#              'prudent': 3,
#              'militia': 45,
#              'asked': 778,
#              'performances': 5,
#              'predominated': 3,
#              'privilege': 15,
#              'schedules': 2,
#              'gathering': 21,
#              'before': 1364,
#              'granny': 2,
#              'heroism': 14,
#              'negligible': 6,
#              'consternation': 8,
#              'enucleation': 3,
#              'apaches': 2,
#              'coastal': 2,
#              'television': 2,
#              'textiles': 3,
#              'enliven': 4,
#              'protestants': 7,
#              'compares': 3,
#              'disappear': 46,
#              'trusted': 17,
#              'ye': 9,
#              'microbes': 2,
#              'creaks': 2,
#              'haney': 2,
#              'contracts': 14,
#              'statutes': 5,
#              'brian': 2,
#              'dooties': 2,
#              'launching': 2,
#              'appomattox': 5,
#              'miscarriages': 2,
#              'innovations': 5,
#              'unaided': 2,
#              'philology': 2,
#              'supervened': 2,
#              'widely': 66,
#              'means': 254,
#              'discomfiture': 5,
#              'logician': 2,
#              'zenith': 2,
#              'commonplaces': 3,
#              'typhus': 4,
#              'sleighs': 12,
#              'aime': 6,
#              'scarlet': 23,
#              'flaubert': 2,
#              'equipped': 11,
#              'buzzing': 11,
#              'haemoptysis': 3,
#              'bastard': 3,
#              'tarso': 2,
#              'hungarian': 8,
#              'bacon': 11,
#              'crumbling': 6,
#              'preamble': 4,
#              'tunnel': 5,
#              'adorning': 2,
#              'patience': 27,
#              'xxxii': 3,
#              'bald': 83,
#              'reparation': 3,
#              'indissoluble': 4,
#              'percent': 2,
#              'bustle': 13,
#              'orlando': 3,
#              'advances': 5,
#              'christians': 8,
#              'sholtos': 2,
#              'elias': 5,
#              'tended': 7,
#              'sixty': 31,
#              'weapons': 13,
#              'adenoma': 25,
#              'interpreted': 9,
#              'sized': 4,
#              'mayflower': 4,
#              'moderation': 11,
#              'retired': 44,
#              'riding': 72,
#              'footnotes': 5,
#              'poisoning': 28,
#              'imprison': 4,
#              'regarded': 111,
#              'bucks': 2,
#              'participating': 2,
#              'liar': 7,
#              'can': 1096,
#              'italians': 6,
#              'bilateral': 10,
#              'sphinxes': 2,
#              'fluttered': 7,
#              'catheterising': 2,
#              'moved': 249,
#              'jolting': 6,
#              'perhaps': 209,
#              'unconciousness': 2,
#              'insidious': 17,
#              'stripping': 6,
#              'doings': 12,
#              'trail': 18,
#              'assistants': 11,
#              'worshiped': 2,
#              'inconvenience': 22,
#              'versus': 6,
#              'sleeker': 3,
#              'scandal': 20,
#              'metatarsus': 2,
#              'flies': 9,
#              'gentlemanly': 2,
#              'retraction': 10,
#              'waxen': 3,
#              'extermination': 5,
#              'expectation': 19,
#              'dishonor': 4,
#              'happier': 14,
#              'apiece': 8,
#              'dinner': 185,
#              'pedal': 2,
#              'erected': 15,
#              'harpoon': 3,
#              'smartened': 2,
#              'kindlier': 2,
#              'unfordable': 2,
#              'stinging': 10,
#              'explicit': 5,
#              'emanations': 4,
#              'hurling': 3,
#              'gauntlet': 7,
#              'rations': 5,
#              'reductions': 6,
#              'granulating': 12,
#              'otradnoe': 34,
#              'tenders': 2,
#              'fedorovich': 2,
#              'cowboy': 10,
#              'everywhere': 61,
#              'vagrant': 3,
#              'scratch': 14,
#              'textbook': 4,
#              'sanitary': 4,
#              'shilling': 5,
#              'alas': 5,
#              'patrols': 3,
#              'condiments': 2,
#              'mortem': 6,
#              'entrenched': 7,
#              'initiate': 5,
#              'wisest': 6,
#              'applies': 5,
#              'earners': 9,
#              'trooped': 2,
#              'realizing': 16,
#              'carbon': 13,
#              'caprices': 2,
#              'th': 52,
#              'deodorant': 2,
#              'lelorgne': 4,
#              'gastric': 6,
#              'arteries': 78,
#              'jeweller': 2,
#              'associations': 8,
#              'journ': 2,
#              'accessed': 4,
#              'twilight': 8,
#              'paymaster': 3,
#              'paterson': 5,
#              'crest': 8,
#              'groaned': 16,
#              'faith': 65,
#              'saxony': 3,
#              'scraggy': 3,
#              'weep': 26,
#              'circulate': 5,
#              'rates': 49,
#              'chirruping': 2,
#              'kerchiefs': 2,
#              'thank': 106,
#              'observantly': 3,
#              'dumb': 7,
#              'bonds': 53,
#              'preceded': 20,
#              'egerton': 2,
#              'suffices': 3,
#              'dupuytren': 2,
#              'atone': 8,
#              'five': 280,
#              'ceiling': 16,
#              'bronchiectasis': 2,
#              'lengthy': 4,
#              'unclothed': 2,
#              'dint': 4,
#              'nurses': 10,
#              'donkey': 2,
#              'secretariat': 2,
#              'spellbound': 4,
#              'reader': 14,
#              'abound': 3,
#              'identically': 2,
#              'repayment': 3,
#              'pliant': 2,
#              'infants': 25,
#              'macewen': 11,
#              'arteritis': 10,
#              'universal': 38,
#              'healing': 107,
#              'heberden': 4,
#              'clasp': 4,
#              'disorderly': 9,
#              'warns': 2,
#              'primary': 153,
#              'artist': 6,
#              'onerous': 4,
#              'fishing': 12,
#              'capitalist': 5,
#              'detailed': 13,
#              'promenades': 2,
#              'cudgel': 9,
#              'plow': 10,
#              'ignatyevna': 4,
#              'snaffle': 2,
#              'rag': 7,
#              'ra': 2,
#              'discoloured': 12,
#              'papier': 2,
#              'assenting': 3,
#              'watery': 12,
#              'eruptions': 10,
#              'plate': 20,
#              'competing': 3,
#              'seemed': 696,
#              'lavater': 2,
#              'dash': 10,
#              'disloyalty': 2,
#              'flinging': 4,
#              'liberate': 5,
#              'dublin': 3,
#              'dramatically': 2,
#              'schemes': 13,
#              'accountability': 3,
#              'ungodly': 2,
#              'concentric': 5,
#              'tut': 12,
#              'surge': 2,
#              'chords': 4,
#              'price': 46,
#              'drissa': 23,
#              ...})

# %% [markdown]
# ###  编辑距离: ###
# 两个词之间的编辑距离定义为使用了几次插入(在词中插入一个单字母), 删除(删除一个单字母), 交换(交换相邻两个字母), 替换(把一个字母换成另一个)的操作从一个词变到另一个词.

# %%
#返回所有与单词 w 编辑距离为 1 的集合
def edits1(word):
    n = len(word)
    return set([word[0:i]+word[i+1:] for i in range(n)] +                     # deletion (0, i-1, i+1, n)
               [word[0:i]+word[i+1]+word[i]+word[i+2:] for i in range(n-1)] + # transposition (0, i-1, i+1, i, i+2, n)
               [word[0:i]+c+word[i+1:] for i in range(n) for c in alphabet] + # alteration (0, i-1, c, i+1, n)
               [word[0:i]+c+word[i:] for i in range(n+1) for c in alphabet])  # insertion (0, i-1, c, i, n)

# %%
# test = "something"
# n = len(test)
# set([test[0:i] + test[i+1:] for i in range(n)])

# %% [markdown]
# 与 something 编辑距离为2的单词居然达到了 114,324 个
#
# 优化:在这些编辑距离小于2的词中间, 只把那些正确的词作为候选词,只能返回 3 个单词: ‘smoothing’, ‘something’ 和 ‘soothing’

# %%
#返回所有与单词 w 编辑距离为 2 的集合
#在这些编辑距离小于2的词中间, 只把那些正确的词作为候选词
# 就相当于经过两次编辑的 (在edits1的基础上，再进行 一次 edits1)
def edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1))

# %% [markdown]
# 正常来说把一个元音拼成另一个的概率要大于辅音 (因为人常常把 hello 打成 hallo 这样); 把单词的第一个字母拼错的概率会相对小, 等等.但是为了简单起见, 选择了一个简单的方法: 编辑距离为1的正确单词比编辑距离为2的优先级高, 而编辑距离为0的正确单词优先级比编辑距离为1的高.

# %%
def known(words): return set(w for w in words if w in NWORDS)

#如果known(set)非空, candidate 就会选取这个集合, 而不继续计算后面的
def correct(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
    return max(candidates, key=lambda w: NWORDS[w])

# %%
correct("Lest")
# Out:
# 'west'

# %%
# word = "lesa"
# candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
# candidates
# max(candidates, key=lambda w: NWORDS[w])
